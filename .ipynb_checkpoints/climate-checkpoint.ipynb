# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model
inspector = inspect(engine)
inspector.get_table_names()

# reflect the tables (measurement, station)
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement= Base.classes.measurement
Station=Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
first_row = session.query(Measurement).first()
first_row.__dict__


# Design a query to retrieve the last 12 months of precipitation data and plot the results
# Calculate the date 1 year ago from the last data point in the database

# Sort the dataframe by date



statement = session.query(Measurement).order_by(Measurement.date.desc()).statement
measurement_df = pd.read_sql_query(statement, session.bind)
measurement_df.head()

mostrecentyear = measurement_df.loc[measurement_df["date"] >= "2016-08-23"]
mostrecentyear


# Save the query results as a Pandas DataFrame and set the index to the date column
recentyear = mostrecentyear.set_index('date')

# Perform a query to retrieve the data and precipitation scores
prcp_only = recentyear["prcp"]
prcp_only

prcp = mostrecentyear.drop(columns="tobs")
prcp = prcp.drop(columns="station")
prcp = prcp.drop(columns="id")
prcp



# Use Pandas Plotting with Matplotlib to plot the data

ax=prcp.plot(x='date', y='prcp', figsize=(13,5))
ax.set_ylabel("inches")
ax

# %%
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1ce229beac8>,
#  'date': '2010-01-01',
#  'tobs': 65.0,
#  'id': 1,
#  'prcp': 0.08,
#  'station': 'USC00519397'}

# %%
# Use Pandas to calculate the summary statistics for the precipitation data
recentyear["prcp"].describe()
# Out:
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000
# Name: prcp, dtype: float64

# %%
# Design a query to show how many stations are available in this dataset?
first_row = session.query(Station).first()
first_row.__dict__

statement2 = session.query(Station).statement
stations_df = pd.read_sql_query(statement2, session.bind)
stations_df.head()
stations_df['station'].count()

#Totalstations = 9
# Out:
# 9

# %%
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1ce22bf5e08>,
#  'station': 'USC00519397',
#  'latitude': 21.2716,
#  'elevation': 3.0,
#  'name': 'WAIKIKI 717.2, HI US',
#  'id': 1,
#  'longitude': -157.8168}

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
active_stations = measurement_df.groupby('station').count()
active_stations

# List the stations and the counts in descending order.
active_stations['id'].sort_values(ascending = False)

#Station with the highest number of temperature observations. = USC00519281
# Out:
# station
# USC00519281    2772
# USC00519397    2724
# USC00513117    2709
# USC00519523    2669
# USC00516128    2612
# USC00514830    2202
# USC00511918    1979
# USC00517948    1372
# USC00518838     511
# Name: id, dtype: int64

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
mostactive = measurement_df.loc[measurement_df["station"] == "USC00519281"]
lowest_temp = mostactive["tobs"].min()
highest_temp = mostactive["tobs"].max()
average_temp = mostactive["tobs"].mean()
lowest_temp
highest_temp
average_temp
print(f"For station USC00519281, the lowest temperature recorded is {lowest_temp}, the highest temperature recorded is {highest_temp}, and the average temperature recorded is {average_temp}." )
# Out:
# For station USC00519281, the lowest temperature recorded is 54.0, the highest temperature recorded is 85.0, and the average temperature recorded is 71.66378066378067.

# %%
# Choose the station with the highest number of temperature observations. = USC00519281
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
mostactive.sort_values('date', ascending=False)
recent_tobs = mostactive.loc[mostactive["date"] >= "2016-08-18"]
tobs_only = recent_tobs["tobs"]
tobs_only.hist(bins=12)

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.  Trip dates July 1-July 10
print(calc_temps('2015-07-01', '2015-07-10'))
# Out:
# [(67.0, 77.125, 83.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

# Build the plot
fig, ax = plt.subplots()
ax.bar(1, 77.125,
       yerr=(83-67),
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)
ax.set_ylabel('Temperature')
ax.set_xticks(range(1))
ax.set_xticklabels('Average Temperature')
ax.set_title('Trip Avg Temp')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

statement_bonus = session.query(Measurement, Station).filter(Measurement.station == Station.station).statement
bonus_df = pd.read_sql_query(statement_bonus, session.bind)
  
julydates = bonus_df.loc[bonus_df["date"] >= "2015-07-01"]
july_dates = julydates.loc[julydates["date"] <= "2015-07-10"]


tripdates = july_dates.drop(columns="tobs")
julydates_precip= tripdates.drop(columns="id")
julydates_precip.sort_values('prcp', ascending=False)
# Out:
#            station        date  prcp      station  \
# 18821  USC00516128  2015-07-10  2.23  USC00516128
# 18819  USC00516128  2015-07-08  1.26  USC00516128
# 14198  USC00519281  2015-07-10  0.48  USC00519281
# 14196  USC00519281  2015-07-08  0.32  USC00519281
# 11471  USC00519523  2015-07-10  0.30  USC00519523
# 4698   USC00513117  2015-07-10  0.29  USC00513117
# 14191  USC00519281  2015-07-03  0.28  USC00519281
# 11469  USC00519523  2015-07-08  0.26  USC00519523
# 18820  USC00516128  2015-07-09  0.13  USC00516128
# 18818  USC00516128  2015-07-07  0.13  USC00516128
# 8596   USC00517948  2015-07-09  0.10  USC00517948
# 4697   USC00513117  2015-07-09  0.05  USC00513117
# 18817  USC00516128  2015-07-06  0.04  USC00516128
# 14197  USC00519281  2015-07-09  0.04  USC00519281
# 1951   USC00519397  2015-07-08  0.03  USC00519397
# 14195  USC00519281  2015-07-07  0.01  USC00519281
# 14189  USC00519281  2015-07-01  0.01  USC00519281
# 4695   USC00513117  2015-07-06  0.01  USC00513117
# ...

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
